# %% [markdown]
# # 2. Calculate the volume of that part of a sphere of unit radius, centered at origin, which is in the first quadrant by throwing method.

# %%
import lcg_randgen as myrand

j = 0
x = 0.1
for i in range(100000000):  # n=100000000
    r1 = myrand(x)
    x = r1
    r2 = myrand(x)
    x = r2
    r3 = myrand(x)
    x = r3
    if r1**2 + r2**2 + r3**2 <= 1:  # equation of sphere: x^2+y^2+z^2=r^2, here r=1
        j += 1
print(j/100000000)
# Out:
# 0.52512263

# %% [markdown]
# # 3. Simulate a 2-dimensional random walk of N = 300, 600, 900 steps, each time starting from the origin. For each walk of different steps use different seeds. Calculate the r.m.s. distance that the walker moves. Compare it with the net displacement. Plot the walks.

# %%
import matplotlib.pyplot as plt
import lcg_randgen as myrand

j = 0
a1 = [0]  # starting point is origin
b1 = [0]
x = myrand(myrand(0.1))  # randomising the seed
n = 300  # no. of walks
for i in range(n):
   x1 = myrand(x)
   x = 2*(x1)-1  # changing range to [-1,1] to include all range of values
   y1 = myrand(x)
   x = 2*(y1)-1
   a1.append(2*(x1)-1)
   b1.append(2*(y1)-1)
   sqdist = (a1[i]-a1[i-1])**2 + (b1[i]-b1[i-1])**2
   j += sqdist

plt.ylim(bottom=-1, top=1)
plt.plot(a1, b1)
rmsdist = (j/n)**(1/2)
print("rms distance by each walk:", rmsdist)
disp = ((a1[-1]-a1[0])**2 + (b1[-1]-b1[0])**2)**(1/2)
print("net displacement:", disp)
# Out:
# rms distance by each walk: 1.112429761160434
# net displacement: 0.6651731544539751

# %%
import matplotlib.pyplot as plt
import lcg_randgen as myrand

j = 0
a1 = [0]  # starting point is origin
b1 = [0]
x = myrand(myrand(0.1))  # randomising the seed
n = 600  # no. of walks
for i in range(n):
   x1 = myrand(x)
   x = 2*(x1)-1  # changing range to [-1,1] to include all range of values
   y1 = myrand(x)
   x = 2*(y1)-1
   a1.append(2*(x1)-1)
   b1.append(2*(y1)-1)
   sqdist = (a1[i]-a1[i-1])**2 + (b1[i]-b1[i-1])**2
   j += sqdist

plt.ylim(bottom=-1, top=1)
plt.plot(a1, b1)
rmsdist = (j/n)**(1/2)
print("rms distance by each walk:", rmsdist)
disp = ((a1[-1]-a1[0])**2 + (b1[-1]-b1[0])**2)**(1/2)
print("net displacement:", disp)
# Out:
# rms distance by each walk: 1.124865809185074
# net displacement: 1.023160135363911

# %%
import matplotlib.pyplot as plt
import lcg_randgen as myrand

j = 0
a1 = [0]  # starting point is origin
b1 = [0]
x = myrand(myrand(0.1))  # randomising the seed
n = 900  # no. of walks
for i in range(n):
   x1 = myrand(x)
   x = 2*(x1)-1  # changing range to [-1,1] to include all range of values
   y1 = myrand(x)
   x = 2*(y1)-1
   a1.append(2*(x1)-1)
   b1.append(2*(y1)-1)
   sqdist = (a1[i]-a1[i-1])**2 + (b1[i]-b1[i-1])**2
   j += sqdist

plt.ylim(bottom=-1, top=1)
plt.plot(a1, b1)
rmsdist = (j/n)**(1/2)
print("rms distance by each walk:", rmsdist)
disp = ((a1[-1]-a1[0])**2 + (b1[-1]-b1[0])**2)**(1/2)
print("net displacement:", disp)
# Out:
# rms distance by each walk: 1.1280838130224824
# net displacement: 1.0391986727381293

# %% [markdown]
# We can observe that rms distance that the walker moves increases with the number of walks taken in orders of 10^-2, while there is no conclusive relation on how the net displacement increases.
